# %% [markdown]
# # Programming Assignment: Building a Robust Data Pipeline
#
# Welcome to the assignment for Data Management in PyTorch.
#
# In earlier examples, you've worked with clean, pre-packaged datasets. In reality, data is rarely that simple. In computer vision, images often come in different sizes and formats and must be preprocessed before a model can learn from them. Manually handling this for thousands of images would be both tedious and error-prone.
#
# In this assignment, you’ll work with the [Plants Classification](https://www.kaggle.com/datasets/marquis03/plants-classification) dataset, which contains 30,000 `.jpg` images across 30 plant species such as aloe vera, banana, spinach, and watermelon. Like many real-world datasets, the images vary in size and quality and are organized into folders by class. For this exercise, you’ll use a subset of 3,000 images.
#
# This is where a data pipeline comes in. You’ll get hands-on experience building a custom dataset, applying the necessary transformations, and loading your data in batches. These are the essential first steps before training a deep learning model.
#
# **What You will do in this Assignment**
#
# * Access and explore the structure of an image dataset.
# * Build a custom `Dataset` class to load your images and labels on demand.
# * Define a series of `transformations`, including resizing, tensor conversion, and `normalization`, to preprocess the data.
# * Define augmentation transforms to enhance the training dataset.
# * Split the dataset into training, validation, and test sets applying the appropriate transforms to each and creating `DataLoader` instances for efficient batching.
#
# Let's get started!

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to submit your solutions or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the `Submit assignment` button on the top right of the page.
# ---

# %% [markdown]
# ## Table of Contents
# - [Imports](#imports)
# - [1 - Data Access](#1---data-access)
#     - [1.1 - Exploring the Dataset](#11---exploring-the-dataset)
#     - [1.2 - Creating a Custom Dataset Class](#12---creating-a-custom-dataset-class)
#         - **[Exercise 1 - PlantsDataset](#exercise-1---plantsdataset)**
#     - [1.3 - Overview of the images in the dataset](#13---overview-of-the-images-in-the-dataset)
# - [2 - Transformations](#2---transformations)
#     - [2.1 - Computing Mean and Standard Deviation](#21---computing-mean-and-standard-deviation)
#     - [2.2 - Defining Transformations](#22---defining-transformations)
#         - **[Exercise 2 - get_transformations](#exercise-2---get_transformations)**
# - [3 - Data Loading](#3---data-loading)
#     - **[Exercise 3 - get_data_loaders](#exercise-3---get_data_loaders)**

# %% [markdown]
# <a name='imports'></a>
# ## Imports

# %%
# !pip install dlai-grader github-content-downloader --quiet
from github_downloader import download_from_github

URL = "https://github.com/rohan-gt/PyTorch-for-Deep-Learning--DeepLearning.AI/tree/master/1.%20PyTorch-%20Fundamentals/3.%20Data%20Management%20in%20PyTorch/Assignments/A1"
download_from_github(url=URL, dest_folder=".")
# !cat plants_dataset.zip.part_* > plants_dataset.zip
# !unzip plants_dataset.zip -d plants_dataset
# Out:
# Downloading content from rohan-gt/PyTorch-for-Deep-Learning--DeepLearning.AI/1.%20PyTorch-%20Fundamentals/3.%20Data%20Management%20in%20PyTorch/Assignments/A1 on branch master...
# Downloaded: ./C1M3_Assignment.ipynb
# Downloaded: ./exp_out_1.png
# Downloaded: ./helper_utils.py
# Downloaded: ./plants_dataset.zip.part_00
# Downloaded: ./plants_dataset.zip.part_01
# Downloaded: ./requirements.txt
# Downloaded: ./unittests.py
# Downloaded: ./unittests_utils.py
# Archive:  plants_dataset.zip
#    creating: plants_dataset/aloevera/
#    creating: plants_dataset/banana/
#    creating: plants_dataset/bilimbi/
#    creating: plants_dataset/cantaloupe/
#    creating: plants_dataset/cassava/
#    creating: plants_dataset/coconut/
#    creating: plants_dataset/corn/
#    creating: plants_dataset/cucumber/
#    creating: plants_dataset/curcuma/
#    creating: plants_dataset/eggplant/
#    creating: plants_dataset/galangal/
#    creating: plants_dataset/ginger/
#    creating: plants_dataset/guava/
#    creating: plants_dataset/kale/
#    creating: plants_dataset/longbeans/
#    creating: plants_dataset/mango/
#    creating: plants_dataset/melon/
#    creating: plants_dataset/orange/
#    creating: plants_dataset/paddy/
#    creating: plants_dataset/papaya/
#    creating: plants_dataset/peperchili/
#    creating: plants_dataset/pineapple/
#    creating: plants_dataset/pomelo/
#    creating: plants_dataset/shallot/
#    creating: plants_dataset/soybeans/
#    creating: plants_dataset/spinach/
#    creating: plants_dataset/sweetpotatoes/
#    creating: plants_dataset/tobacco/
#    creating: plants_dataset/waterapple/
#    creating: plants_dataset/watermelon/
#   inflating: plants_dataset/classname.txt
#   inflating: plants_dataset/df_labels.csv
#   inflating: plants_dataset/df_labels_orig.csv
#   inflating: plants_dataset/aloevera/aloevera700.jpg
#   inflating: plants_dataset/aloevera/aloevera701.jpg
#   inflating: plants_dataset/aloevera/aloevera702.jpg
#   inflating: plants_dataset/aloevera/aloevera703.jpg
#   inflating: plants_dataset/aloevera/aloevera704.jpg
#   inflating: plants_dataset/aloevera/aloevera705.jpg
#   inflating: plants_dataset/aloevera/aloevera706.jpg
#   inflating: plants_dataset/aloevera/aloevera707.jpg
#   inflating: plants_dataset/aloevera/aloevera708.jpg
#   inflating: plants_dataset/aloevera/aloevera709.jpg
#   inflating: plants_dataset/aloevera/aloevera710.jpg
#   inflating: plants_dataset/aloevera/aloevera711.jpg
#   inflating: plants_dataset/aloevera/aloevera712.jpg
#   inflating: plants_dataset/aloevera/aloevera713.jpg
#   inflating: plants_dataset/aloevera/aloevera714.jpg
#   inflating: plants_dataset/aloevera/aloevera715.jpg
#   inflating: plants_dataset/aloevera/aloevera716.jpg
#   inflating: plants_dataset/aloevera/aloevera717.jpg
#   inflating: plants_dataset/aloevera/aloevera718.jpg
#   inflating: plants_dataset/aloevera/aloevera719.jpg
#   inflating: plants_dataset/aloevera/aloevera720.jpg
#   inflating: plants_dataset/aloevera/aloevera721.jpg
#   inflating: plants_dataset/aloevera/aloevera722.jpg
#   inflating: plants_dataset/aloevera/aloevera723.jpg
#   inflating: plants_dataset/aloevera/aloevera724.jpg
#   inflating: plants_dataset/aloevera/aloevera725.jpg
#   inflating: plants_dataset/aloevera/aloevera726.jpg
#   inflating: plants_dataset/aloevera/aloevera727.jpg
#   inflating: plants_dataset/aloevera/aloevera728.jpg
#   inflating: plants_dataset/aloevera/aloevera729.jpg
#   inflating: plants_dataset/aloevera/aloevera730.jpg
#   inflating: plants_dataset/aloevera/aloevera731.jpg
#   inflating: plants_dataset/aloevera/aloevera732.jpg
#   inflating: plants_dataset/aloevera/aloevera733.jpg
#   inflating: plants_dataset/aloevera/aloevera734.jpg
#   inflating: plants_dataset/aloevera/aloevera735.jpg
#   inflating: plants_dataset/aloevera/aloevera736.jpg
#   inflating: plants_dataset/aloevera/aloevera737.jpg
#   inflating: plants_dataset/aloevera/aloevera738.jpg
#   inflating: plants_dataset/aloevera/aloevera739.jpg
#   inflating: plants_dataset/aloevera/aloevera740.jpg
#   inflating: plants_dataset/aloevera/aloevera741.jpg
#   inflating: plants_dataset/aloevera/aloevera742.jpg
#   inflating: plants_dataset/aloevera/aloevera743.jpg
#   inflating: plants_dataset/aloevera/aloevera744.jpg
#   inflating: plants_dataset/aloevera/aloevera745.jpg
#   inflating: plants_dataset/aloevera/aloevera746.jpg
#   inflating: plants_dataset/aloevera/aloevera747.jpg
#   inflating: plants_dataset/aloevera/aloevera748.jpg
#   inflating: plants_dataset/aloevera/aloevera749.jpg
#   inflating: plants_dataset/aloevera/aloevera750.jpg
#   inflating: plants_dataset/aloevera/aloevera751.jpg
#   inflating: plants_dataset/aloevera/aloevera752.jpg
#   inflating: plants_dataset/aloevera/aloevera753.jpg
#   inflating: plants_dataset/aloevera/aloevera754.jpg
#   inflating: plants_dataset/aloevera/aloevera755.jpg
#   inflating: plants_dataset/aloevera/aloevera756.jpg
#   inflating: plants_dataset/aloevera/aloevera757.jpg
#   inflating: plants_dataset/aloevera/aloevera758.jpg
#   inflating: plants_dataset/aloevera/aloevera759.jpg
#   inflating: plants_dataset/aloevera/aloevera760.jpg
#   inflating: plants_dataset/aloevera/aloevera761.jpg
#   inflating: plants_dataset/aloevera/aloevera762.jpg
#   inflating: plants_dataset/aloevera/aloevera763.jpg
#   inflating: plants_dataset/aloevera/aloevera764.jpg
#   inflating: plants_dataset/aloevera/aloevera765.jpg
#   inflating: plants_dataset/aloevera/aloevera766.jpg
#   inflating: plants_dataset/aloevera/aloevera767.jpg
#   inflating: plants_dataset/aloevera/aloevera768.jpg
#   inflating: plants_dataset/aloevera/aloevera769.jpg
#   inflating: plants_dataset/aloevera/aloevera770.jpg
#   inflating: plants_dataset/aloevera/aloevera771.jpg
#   inflating: plants_dataset/aloevera/aloevera772.jpg
#   inflating: plants_dataset/aloevera/aloevera773.jpg
#   inflating: plants_dataset/aloevera/aloevera774.jpg
#   inflating: plants_dataset/aloevera/aloevera775.jpg
#   inflating: plants_dataset/aloevera/aloevera776.jpg
#   inflating: plants_dataset/aloevera/aloevera777.jpg
#   inflating: plants_dataset/aloevera/aloevera778.jpg
#   inflating: plants_dataset/aloevera/aloevera779.jpg
#   inflating: plants_dataset/aloevera/aloevera780.jpg
#   inflating: plants_dataset/aloevera/aloevera781.jpg
#   inflating: plants_dataset/aloevera/aloevera782.jpg
#   inflating: plants_dataset/aloevera/aloevera783.jpg
#   inflating: plants_dataset/aloevera/aloevera784.jpg
#   inflating: plants_dataset/aloevera/aloevera785.jpg
#   inflating: plants_dataset/aloevera/aloevera786.jpg
#   inflating: plants_dataset/aloevera/aloevera787.jpg
#   inflating: plants_dataset/aloevera/aloevera788.jpg
#   inflating: plants_dataset/aloevera/aloevera789.jpg
#   inflating: plants_dataset/aloevera/aloevera790.jpg
#   inflating: plants_dataset/aloevera/aloevera791.jpg
#   inflating: plants_dataset/aloevera/aloevera792.jpg
#   inflating: plants_dataset/aloevera/aloevera793.jpg
#   inflating: plants_dataset/aloevera/aloevera794.jpg
#   inflating: plants_dataset/aloevera/aloevera795.jpg
#   inflating: plants_dataset/aloevera/aloevera796.jpg
#   inflating: plants_dataset/aloevera/aloevera797.jpg
#   inflating: plants_dataset/aloevera/aloevera798.jpg
#   inflating: plants_dataset/aloevera/aloevera799.jpg
#   inflating: plants_dataset/banana/banana700.jpg
#   inflating: plants_dataset/banana/banana701.jpg
#   inflating: plants_dataset/banana/banana702.jpg
#   inflating: plants_dataset/banana/banana703.jpg
#   inflating: plants_dataset/banana/banana704.jpg
#   inflating: plants_dataset/banana/banana705.jpg
#   inflating: plants_dataset/banana/banana706.jpg
#   inflating: plants_dataset/banana/banana707.jpg
#   inflating: plants_dataset/banana/banana708.jpg
#   inflating: plants_dataset/banana/banana709.jpg
#   inflating: plants_dataset/banana/banana710.jpg
#   inflating: plants_dataset/banana/banana711.jpg
#   inflating: plants_dataset/banana/banana712.jpg
#   inflating: plants_dataset/banana/banana713.jpg
#   inflating: plants_dataset/banana/banana714.jpg
#   inflating: plants_dataset/banana/banana715.jpg
#   inflating: plants_dataset/banana/banana716.jpg
#   inflating: plants_dataset/banana/banana717.jpg
#   inflating: plants_dataset/banana/banana718.jpg
#   inflating: plants_dataset/banana/banana719.jpg
#   inflating: plants_dataset/banana/banana720.jpg
#   inflating: plants_dataset/banana/banana721.jpg
#   inflating: plants_dataset/banana/banana722.jpg
#   inflating: plants_dataset/banana/banana723.jpg
#   inflating: plants_dataset/banana/banana724.jpg
#   inflating: plants_dataset/banana/banana725.jpg
#   inflating: plants_dataset/banana/banana726.jpg
#   inflating: plants_dataset/banana/banana727.jpg
#   inflating: plants_dataset/banana/banana728.jpg
#   inflating: plants_dataset/banana/banana729.jpg
#   inflating: plants_dataset/banana/banana730.jpg
#   inflating: plants_dataset/banana/banana731.jpg
#   inflating: plants_dataset/banana/banana732.jpg
#   inflating: plants_dataset/banana/banana733.jpg
#   inflating: plants_dataset/banana/banana734.jpg
#   inflating: plants_dataset/banana/banana735.jpg
#   inflating: plants_dataset/banana/banana736.jpg
#   inflating: plants_dataset/banana/banana737.jpg
#   inflating: plants_dataset/banana/banana738.jpg
#   inflating: plants_dataset/banana/banana739.jpg
#   inflating: plants_dataset/banana/banana740.jpg
#   inflating: plants_dataset/banana/banana741.jpg
#   inflating: plants_dataset/banana/banana742.jpg
#   inflating: plants_dataset/banana/banana743.jpg
#   inflating: plants_dataset/banana/banana744.jpg
#   inflating: plants_dataset/banana/banana745.jpg
#   inflating: plants_dataset/banana/banana746.jpg
#   inflating: plants_dataset/banana/banana747.jpg
#   inflating: plants_dataset/banana/banana748.jpg
#   inflating: plants_dataset/banana/banana749.jpg
#   inflating: plants_dataset/banana/banana750.jpg
#   inflating: plants_dataset/banana/banana751.jpg
#   inflating: plants_dataset/banana/banana752.jpg
#   inflating: plants_dataset/banana/banana753.jpg
#   inflating: plants_dataset/banana/banana754.jpg
#   inflating: plants_dataset/banana/banana755.jpg
#   inflating: plants_dataset/banana/banana756.jpg
#   inflating: plants_dataset/banana/banana757.jpg
#   inflating: plants_dataset/banana/banana758.jpg
#   inflating: plants_dataset/banana/banana759.jpg
#   inflating: plants_dataset/banana/banana760.jpg
#   inflating: plants_dataset/banana/banana761.jpg
#   inflating: plants_dataset/banana/banana762.jpg
#   inflating: plants_dataset/banana/banana763.jpg
#   inflating: plants_dataset/banana/banana764.jpg
#   inflating: plants_dataset/banana/banana765.jpg
#   inflating: plants_dataset/banana/banana766.jpg
#   inflating: plants_dataset/banana/banana767.jpg
#   inflating: plants_dataset/banana/banana768.jpg
#   inflating: plants_dataset/banana/banana769.jpg
#   inflating: plants_dataset/banana/banana770.jpg
#   inflating: plants_dataset/banana/banana771.jpg
#   inflating: plants_dataset/banana/banana772.jpg
#   inflating: plants_dataset/banana/banana773.jpg
#   inflating: plants_dataset/banana/banana774.jpg
#   inflating: plants_dataset/banana/banana775.jpg
#   inflating: plants_dataset/banana/banana776.jpg
#   inflating: plants_dataset/banana/banana777.jpg
#   inflating: plants_dataset/banana/banana778.jpg
#   inflating: plants_dataset/banana/banana779.jpg
#   inflating: plants_dataset/banana/banana780.jpg
#   inflating: plants_dataset/banana/banana781.jpg
#   inflating: plants_dataset/banana/banana782.jpg
#   inflating: plants_dataset/banana/banana783.jpg
#   inflating: plants_dataset/banana/banana784.jpg
#   inflating: plants_dataset/banana/banana785.jpg
#   inflating: plants_dataset/banana/banana786.jpg
#   inflating: plants_dataset/banana/banana787.jpg
#   inflating: plants_dataset/banana/banana788.jpg
#   inflating: plants_dataset/banana/banana789.jpg
#   inflating: plants_dataset/banana/banana790.jpg
#   inflating: plants_dataset/banana/banana791.jpg
#   inflating: plants_dataset/banana/banana792.jpg
#   inflating: plants_dataset/banana/banana793.jpg
#   inflating: plants_dataset/banana/banana794.jpg
#   inflating: plants_dataset/banana/banana795.jpg
#   inflating: plants_dataset/banana/banana796.jpg
#   inflating: plants_dataset/banana/banana797.jpg
#   inflating: plants_dataset/banana/banana798.jpg
#   inflating: plants_dataset/banana/banana799.jpg
#   inflating: plants_dataset/bilimbi/bilimbi700.jpg
#   inflating: plants_dataset/bilimbi/bilimbi701.jpg
#   inflating: plants_dataset/bilimbi/bilimbi702.jpg
#   inflating: plants_dataset/bilimbi/bilimbi703.jpg
#   inflating: plants_dataset/bilimbi/bilimbi704.jpg
#   inflating: plants_dataset/bilimbi/bilimbi705.jpg
#   inflating: plants_dataset/bilimbi/bilimbi706.jpg
#   inflating: plants_dataset/bilimbi/bilimbi707.jpg
#   inflating: plants_dataset/bilimbi/bilimbi708.jpg
#   inflating: plants_dataset/bilimbi/bilimbi709.jpg
#   inflating: plants_dataset/bilimbi/bilimbi710.jpg
#   inflating: plants_dataset/bilimbi/bilimbi711.jpg
#   inflating: plants_dataset/bilimbi/bilimbi712.jpg
#   inflating: plants_dataset/bilimbi/bilimbi713.jpg
#   inflating: plants_dataset/bilimbi/bilimbi714.jpg
#   inflating: plants_dataset/bilimbi/bilimbi715.jpg
#   inflating: plants_dataset/bilimbi/bilimbi716.jpg
#   inflating: plants_dataset/bilimbi/bilimbi717.jpg
#   inflating: plants_dataset/bilimbi/bilimbi718.jpg
#   inflating: plants_dataset/bilimbi/bilimbi719.jpg
#   inflating: plants_dataset/bilimbi/bilimbi720.jpg
#   inflating: plants_dataset/bilimbi/bilimbi721.jpg
#   inflating: plants_dataset/bilimbi/bilimbi722.jpg
#   inflating: plants_dataset/bilimbi/bilimbi723.jpg
#   inflating: plants_dataset/bilimbi/bilimbi724.jpg
#   inflating: plants_dataset/bilimbi/bilimbi725.jpg
#   inflating: plants_dataset/bilimbi/bilimbi726.jpg
#   inflating: plants_dataset/bilimbi/bilimbi727.jpg
#   inflating: plants_dataset/bilimbi/bilimbi728.jpg
#   inflating: plants_dataset/bilimbi/bilimbi729.jpg
#   inflating: plants_dataset/bilimbi/bilimbi730.jpg
#   inflating: plants_dataset/bilimbi/bilimbi731.jpg
#   inflating: plants_dataset/bilimbi/bilimbi732.jpg
#   inflating: plants_dataset/bilimbi/bilimbi733.jpg
#   inflating: plants_dataset/bilimbi/bilimbi734.jpg
#   inflating: plants_dataset/bilimbi/bilimbi735.jpg
#   inflating: plants_dataset/bilimbi/bilimbi736.jpg
#   inflating: plants_dataset/bilimbi/bilimbi737.jpg
#   inflating: plants_dataset/bilimbi/bilimbi738.jpg
#   inflating: plants_dataset/bilimbi/bilimbi739.jpg
#   inflating: plants_dataset/bilimbi/bilimbi740.jpg
#   inflating: plants_dataset/bilimbi/bilimbi741.jpg
#   inflating: plants_dataset/bilimbi/bilimbi742.jpg
#   inflating: plants_dataset/bilimbi/bilimbi743.jpg
#   inflating: plants_dataset/bilimbi/bilimbi744.jpg
#   inflating: plants_dataset/bilimbi/bilimbi745.jpg
#   inflating: plants_dataset/bilimbi/bilimbi746.jpg
#   inflating: plants_dataset/bilimbi/bilimbi747.jpg
#   inflating: plants_dataset/bilimbi/bilimbi748.jpg
#   inflating: plants_dataset/bilimbi/bilimbi749.jpg
#   inflating: plants_dataset/bilimbi/bilimbi750.jpg
#   inflating: plants_dataset/bilimbi/bilimbi751.jpg
#   inflating: plants_dataset/bilimbi/bilimbi752.jpg
#   inflating: plants_dataset/bilimbi/bilimbi753.jpg
#   inflating: plants_dataset/bilimbi/bilimbi754.jpg
#   inflating: plants_dataset/bilimbi/bilimbi755.jpg
#   inflating: plants_dataset/bilimbi/bilimbi756.jpg
#   inflating: plants_dataset/bilimbi/bilimbi757.jpg
#   inflating: plants_dataset/bilimbi/bilimbi758.jpg
#   inflating: plants_dataset/bilimbi/bilimbi759.jpg
#   inflating: plants_dataset/bilimbi/bilimbi760.jpg
#   inflating: plants_dataset/bilimbi/bilimbi761.jpg
#   inflating: plants_dataset/bilimbi/bilimbi762.jpg
#   inflating: plants_dataset/bilimbi/bilimbi763.jpg
#   inflating: plants_dataset/bilimbi/bilimbi764.jpg
#   inflating: plants_dataset/bilimbi/bilimbi765.jpg
#   inflating: plants_dataset/bilimbi/bilimbi766.jpg
#   inflating: plants_dataset/bilimbi/bilimbi767.jpg
#   inflating: plants_dataset/bilimbi/bilimbi768.jpg
#   inflating: plants_dataset/bilimbi/bilimbi769.jpg
#   inflating: plants_dataset/bilimbi/bilimbi770.jpg
#   inflating: plants_dataset/bilimbi/bilimbi771.jpg
#   inflating: plants_dataset/bilimbi/bilimbi772.jpg
#   inflating: plants_dataset/bilimbi/bilimbi773.jpg
#   inflating: plants_dataset/bilimbi/bilimbi774.jpg
#   inflating: plants_dataset/bilimbi/bilimbi775.jpg
#   inflating: plants_dataset/bilimbi/bilimbi776.jpg
#   inflating: plants_dataset/bilimbi/bilimbi777.jpg
#   inflating: plants_dataset/bilimbi/bilimbi778.jpg
#   inflating: plants_dataset/bilimbi/bilimbi779.jpg
#   inflating: plants_dataset/bilimbi/bilimbi780.jpg
#   inflating: plants_dataset/bilimbi/bilimbi781.jpg
#   inflating: plants_dataset/bilimbi/bilimbi782.jpg
#   inflating: plants_dataset/bilimbi/bilimbi783.jpg
#   inflating: plants_dataset/bilimbi/bilimbi784.jpg
#   inflating: plants_dataset/bilimbi/bilimbi785.jpg
#   inflating: plants_dataset/bilimbi/bilimbi786.jpg
#   inflating: plants_dataset/bilimbi/bilimbi787.jpg
#   inflating: plants_dataset/bilimbi/bilimbi788.jpg
#   inflating: plants_dataset/bilimbi/bilimbi789.jpg
#   inflating: plants_dataset/bilimbi/bilimbi790.jpg
#   inflating: plants_dataset/bilimbi/bilimbi791.jpg
#   inflating: plants_dataset/bilimbi/bilimbi792.jpg
#   inflating: plants_dataset/bilimbi/bilimbi793.jpg
#   inflating: plants_dataset/bilimbi/bilimbi794.jpg
#   inflating: plants_dataset/bilimbi/bilimbi795.jpg
#   inflating: plants_dataset/bilimbi/bilimbi796.jpg
#   inflating: plants_dataset/bilimbi/bilimbi797.jpg
#   inflating: plants_dataset/bilimbi/bilimbi798.jpg
#   inflating: plants_dataset/bilimbi/bilimbi799.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe700.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe701.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe702.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe703.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe704.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe705.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe706.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe707.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe708.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe709.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe710.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe711.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe712.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe713.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe714.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe715.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe716.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe717.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe718.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe719.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe720.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe721.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe722.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe723.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe724.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe725.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe726.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe727.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe728.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe729.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe730.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe731.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe732.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe733.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe734.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe735.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe736.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe737.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe738.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe739.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe740.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe741.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe742.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe743.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe744.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe745.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe746.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe747.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe748.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe749.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe750.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe751.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe752.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe753.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe754.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe755.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe756.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe757.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe758.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe759.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe760.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe761.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe762.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe763.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe764.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe765.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe766.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe767.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe768.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe769.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe770.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe771.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe772.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe773.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe774.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe775.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe776.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe777.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe778.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe779.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe780.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe781.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe782.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe783.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe784.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe785.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe786.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe787.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe788.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe789.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe790.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe791.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe792.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe793.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe794.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe795.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe796.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe797.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe798.jpg
#   inflating: plants_dataset/cantaloupe/cantaloupe799.jpg
#   inflating: plants_dataset/cassava/cassava700.jpg
#   inflating: plants_dataset/cassava/cassava701.jpg
#   inflating: plants_dataset/cassava/cassava702.jpg
#   inflating: plants_dataset/cassava/cassava703.jpg
#   inflating: plants_dataset/cassava/cassava704.jpg
#   inflating: plants_dataset/cassava/cassava705.jpg
#   inflating: plants_dataset/cassava/cassava706.jpg
#   inflating: plants_dataset/cassava/cassava707.jpg
#   inflating: plants_dataset/cassava/cassava708.jpg
#   inflating: plants_dataset/cassava/cassava709.jpg
#   inflating: plants_dataset/cassava/cassava710.jpg
#   inflating: plants_dataset/cassava/cassava711.jpg
#   inflating: plants_dataset/cassava/cassava712.jpg
#   inflating: plants_dataset/cassava/cassava713.jpg
#   inflating: plants_dataset/cassava/cassava714.jpg
#   inflating: plants_dataset/cassava/cassava715.jpg
#   inflating: plants_dataset/cassava/cassava716.jpg
#   inflating: plants_dataset/cassava/cassava717.jpg
#   inflating: plants_dataset/cassava/cassava718.jpg
#   inflating: plants_dataset/cassava/cassava719.jpg
#   inflating: plants_dataset/cassava/cassava720.jpg
#   inflating: plants_dataset/cassava/cassava721.jpg
#   inflating: plants_dataset/cassava/cassava722.jpg
#   inflating: plants_dataset/cassava/cassava723.jpg
#   inflating: plants_dataset/cassava/cassava724.jpg
#   inflating: plants_dataset/cassava/cassava725.jpg
#   inflating: plants_dataset/cassava/cassava726.jpg
#   inflating: plants_dataset/cassava/cassava727.jpg
#   inflating: plants_dataset/cassava/cassava728.jpg
#   inflating: plants_dataset/cassava/cassava729.jpg
#   inflating: plants_dataset/cassava/cassava730.jpg
#   inflating: plants_dataset/cassava/cassava731.jpg
#   inflating: plants_dataset/cassava/cassava732.jpg
#   inflating: plants_dataset/cassava/cassava733.jpg
#   inflating: plants_dataset/cassava/cassava734.jpg
#   inflating: plants_dataset/cassava/cassava735.jpg
#   inflating: plants_dataset/cassava/cassava736.jpg
#   inflating: plants_dataset/cassava/cassava737.jpg
#   inflating: plants_dataset/cassava/cassava738.jpg
#   inflating: plants_dataset/cassava/cassava739.jpg
#   inflating: plants_dataset/cassava/cassava740.jpg
#   inflating: plants_dataset/cassava/cassava741.jpg
#   inflating: plants_dataset/cassava/cassava742.jpg
#   inflating: plants_dataset/cassava/cassava743.jpg
#   inflating: plants_dataset/cassava/cassava744.jpg
#   inflating: plants_dataset/cassava/cassava745.jpg
#   inflating: plants_dataset/cassava/cassava746.jpg
#   inflating: plants_dataset/cassava/cassava747.jpg
#   inflating: plants_dataset/cassava/cassava748.jpg
#   inflating: plants_dataset/cassava/cassava749.jpg
#   inflating: plants_dataset/cassava/cassava750.jpg
#   inflating: plants_dataset/cassava/cassava751.jpg
#   inflating: plants_dataset/cassava/cassava752.jpg
#   inflating: plants_dataset/cassava/cassava753.jpg
#   inflating: plants_dataset/cassava/cassava754.jpg
#   inflating: plants_dataset/cassava/cassava755.jpg
#   inflating: plants_dataset/cassava/cassava756.jpg
#   inflating: plants_dataset/cassava/cassava757.jpg
#   inflating: plants_dataset/cassava/cassava758.jpg
#   inflating: plants_dataset/cassava/cassava759.jpg
#   inflating: plants_dataset/cassava/cassava760.jpg
#   inflating: plants_dataset/cassava/cassava761.jpg
#   inflating: plants_dataset/cassava/cassava762.jpg
#   inflating: plants_dataset/cassava/cassava763.jpg
#   inflating: plants_dataset/cassava/cassava764.jpg
#   inflating: plants_dataset/cassava/cassava765.jpg
#   inflating: plants_dataset/cassava/cassava766.jpg
#   inflating: plants_dataset/cassava/cassava767.jpg
#   inflating: plants_dataset/cassava/cassava768.jpg
#   inflating: plants_dataset/cassava/cassava769.jpg
#   inflating: plants_dataset/cassava/cassava770.jpg
#   inflating: plants_dataset/cassava/cassava771.jpg
#   inflating: plants_dataset/cassava/cassava772.jpg
#   inflating: plants_dataset/cassava/cassava773.jpg
#   inflating: plants_dataset/cassava/cassava774.jpg
#   inflating: plants_dataset/cassava/cassava775.jpg
#   inflating: plants_dataset/cassava/cassava776.jpg
#   inflating: plants_dataset/cassava/cassava777.jpg
#   inflating: plants_dataset/cassava/cassava778.jpg
#   inflating: plants_dataset/cassava/cassava779.jpg
#   inflating: plants_dataset/cassava/cassava780.jpg
#   inflating: plants_dataset/cassava/cassava781.jpg
#   inflating: plants_dataset/cassava/cassava782.jpg
#   inflating: plants_dataset/cassava/cassava783.jpg
#   inflating: plants_dataset/cassava/cassava784.jpg
#   inflating: plants_dataset/cassava/cassava785.jpg
#   inflating: plants_dataset/cassava/cassava786.jpg
#   inflating: plants_dataset/cassava/cassava787.jpg
#   inflating: plants_dataset/cassava/cassava788.jpg
#   inflating: plants_dataset/cassava/cassava789.jpg
#   inflating: plants_dataset/cassava/cassava790.jpg
#   inflating: plants_dataset/cassava/cassava791.jpg
#   inflating: plants_dataset/cassava/cassava792.jpg
#   inflating: plants_dataset/cassava/cassava793.jpg
#   inflating: plants_dataset/cassava/cassava794.jpg
#   inflating: plants_dataset/cassava/cassava795.jpg
#   inflating: plants_dataset/cassava/cassava796.jpg
#   inflating: plants_dataset/cassava/cassava797.jpg
#   inflating: plants_dataset/cassava/cassava798.jpg
#   inflating: plants_dataset/cassava/cassava799.jpg
#   inflating: plants_dataset/coconut/coconut700.jpg
#   inflating: plants_dataset/coconut/coconut701.jpg
#   inflating: plants_dataset/coconut/coconut702.jpg
#   inflating: plants_dataset/coconut/coconut703.jpg
#   inflating: plants_dataset/coconut/coconut704.jpg
#   inflating: plants_dataset/coconut/coconut705.jpg
#   inflating: plants_dataset/coconut/coconut706.jpg
#   inflating: plants_dataset/coconut/coconut707.jpg
#   inflating: plants_dataset/coconut/coconut708.jpg
#   inflating: plants_dataset/coconut/coconut709.jpg
#   inflating: plants_dataset/coconut/coconut710.jpg
#   inflating: plants_dataset/coconut/coconut711.jpg
#   inflating: plants_dataset/coconut/coconut712.jpg
#   inflating: plants_dataset/coconut/coconut713.jpg
#   inflating: plants_dataset/coconut/coconut714.jpg
#   inflating: plants_dataset/coconut/coconut715.jpg
#   inflating: plants_dataset/coconut/coconut716.jpg
#   inflating: plants_dataset/coconut/coconut717.jpg
#   inflating: plants_dataset/coconut/coconut718.jpg
#   inflating: plants_dataset/coconut/coconut719.jpg
#   inflating: plants_dataset/coconut/coconut720.jpg
#   inflating: plants_dataset/coconut/coconut721.jpg
#   inflating: plants_dataset/coconut/coconut722.jpg
#   inflating: plants_dataset/coconut/coconut723.jpg
#   inflating: plants_dataset/coconut/coconut724.jpg
#   inflating: plants_dataset/coconut/coconut725.jpg
#   inflating: plants_dataset/coconut/coconut726.jpg
#   inflating: plants_dataset/coconut/coconut727.jpg
#   inflating: plants_dataset/coconut/coconut728.jpg
#   inflating: plants_dataset/coconut/coconut729.jpg
#   inflating: plants_dataset/coconut/coconut730.jpg
#   inflating: plants_dataset/coconut/coconut731.jpg
#   inflating: plants_dataset/coconut/coconut732.jpg
#   inflating: plants_dataset/coconut/coconut733.jpg
#   inflating: plants_dataset/coconut/coconut734.jpg
#   inflating: plants_dataset/coconut/coconut735.jpg
#   inflating: plants_dataset/coconut/coconut736.jpg
#   inflating: plants_dataset/coconut/coconut737.jpg
#   inflating: plants_dataset/coconut/coconut738.jpg
#   inflating: plants_dataset/coconut/coconut739.jpg
#   inflating: plants_dataset/coconut/coconut740.jpg
#   inflating: plants_dataset/coconut/coconut741.jpg
#   inflating: plants_dataset/coconut/coconut742.jpg
#   inflating: plants_dataset/coconut/coconut743.jpg
#   inflating: plants_dataset/coconut/coconut744.jpg
#   inflating: plants_dataset/coconut/coconut745.jpg
#   inflating: plants_dataset/coconut/coconut746.jpg
#   inflating: plants_dataset/coconut/coconut747.jpg
#   inflating: plants_dataset/coconut/coconut748.jpg
#   inflating: plants_dataset/coconut/coconut749.jpg
#   inflating: plants_dataset/coconut/coconut750.jpg
#   inflating: plants_dataset/coconut/coconut751.jpg
#   inflating: plants_dataset/coconut/coconut752.jpg
#   inflating: plants_dataset/coconut/coconut753.jpg
#   inflating: plants_dataset/coconut/coconut754.jpg
#   inflating: plants_dataset/coconut/coconut755.jpg
#   inflating: plants_dataset/coconut/coconut756.jpg
#   inflating: plants_dataset/coconut/coconut757.jpg
#   inflating: plants_dataset/coconut/coconut758.jpg
#   inflating: plants_dataset/coconut/coconut759.jpg
#   inflating: plants_dataset/coconut/coconut760.jpg
#   inflating: plants_dataset/coconut/coconut761.jpg
#   inflating: plants_dataset/coconut/coconut762.jpg
#   inflating: plants_dataset/coconut/coconut763.jpg
#   inflating: plants_dataset/coconut/coconut764.jpg
#   inflating: plants_dataset/coconut/coconut765.jpg
#   inflating: plants_dataset/coconut/coconut766.jpg
#   inflating: plants_dataset/coconut/coconut767.jpg
#   inflating: plants_dataset/coconut/coconut768.jpg
#   inflating: plants_dataset/coconut/coconut769.jpg
#   inflating: plants_dataset/coconut/coconut770.jpg
#   inflating: plants_dataset/coconut/coconut771.jpg
#   inflating: plants_dataset/coconut/coconut772.jpg
#   inflating: plants_dataset/coconut/coconut773.jpg
#   inflating: plants_dataset/coconut/coconut774.jpg
#   inflating: plants_dataset/coconut/coconut775.jpg
#   inflating: plants_dataset/coconut/coconut776.jpg
#   inflating: plants_dataset/coconut/coconut777.jpg
#   inflating: plants_dataset/coconut/coconut778.jpg
#   inflating: plants_dataset/coconut/coconut779.jpg
#   inflating: plants_dataset/coconut/coconut780.jpg
#   inflating: plants_dataset/coconut/coconut781.jpg
#   inflating: plants_dataset/coconut/coconut782.jpg
#   inflating: plants_dataset/coconut/coconut783.jpg
#   inflating: plants_dataset/coconut/coconut784.jpg
#   inflating: plants_dataset/coconut/coconut785.jpg
#   inflating: plants_dataset/coconut/coconut786.jpg
#   inflating: plants_dataset/coconut/coconut787.jpg
#   inflating: plants_dataset/coconut/coconut788.jpg
#   inflating: plants_dataset/coconut/coconut789.jpg
#   inflating: plants_dataset/coconut/coconut790.jpg
#   inflating: plants_dataset/coconut/coconut791.jpg
#   inflating: plants_dataset/coconut/coconut792.jpg
#   inflating: plants_dataset/coconut/coconut793.jpg
#   inflating: plants_dataset/coconut/coconut794.jpg
#   inflating: plants_dataset/coconut/coconut795.jpg
#   inflating: plants_dataset/coconut/coconut796.jpg
#   inflating: plants_dataset/coconut/coconut797.jpg
#   inflating: plants_dataset/coconut/coconut798.jpg
#   inflating: plants_dataset/coconut/coconut799.jpg
#   inflating: plants_dataset/corn/corn700.jpg
#   inflating: plants_dataset/corn/corn701.jpg
#   inflating: plants_dataset/corn/corn702.jpg
#   inflating: plants_dataset/corn/corn703.jpg
#   inflating: plants_dataset/corn/corn704.jpg
#   inflating: plants_dataset/corn/corn705.jpg
#   inflating: plants_dataset/corn/corn706.jpg
#   inflating: plants_dataset/corn/corn707.jpg
#   inflating: plants_dataset/corn/corn708.jpg
#   inflating: plants_dataset/corn/corn709.jpg
#   inflating: plants_dataset/corn/corn710.jpg
#   inflating: plants_dataset/corn/corn711.jpg
#   inflating: plants_dataset/corn/corn712.jpg
#   inflating: plants_dataset/corn/corn713.jpg
#   inflating: plants_dataset/corn/corn714.jpg
#   inflating: plants_dataset/corn/corn715.jpg
#   inflating: plants_dataset/corn/corn716.jpg
#   inflating: plants_dataset/corn/corn717.jpg
#   inflating: plants_dataset/corn/corn718.jpg
#   inflating: plants_dataset/corn/corn719.jpg
#   inflating: plants_dataset/corn/corn720.jpg
#   inflating: plants_dataset/corn/corn721.jpg
#   inflating: plants_dataset/corn/corn722.jpg
#   inflating: plants_dataset/corn/corn723.jpg
#   inflating: plants_dataset/corn/corn724.jpg
#   inflating: plants_dataset/corn/corn725.jpg
#   inflating: plants_dataset/corn/corn726.jpg
#   inflating: plants_dataset/corn/corn727.jpg
#   inflating: plants_dataset/corn/corn728.jpg
#   inflating: plants_dataset/corn/corn729.jpg
#   inflating: plants_dataset/corn/corn730.jpg
#   inflating: plants_dataset/corn/corn731.jpg
#   inflating: plants_dataset/corn/corn732.jpg
#   inflating: plants_dataset/corn/corn733.jpg
#   inflating: plants_dataset/corn/corn734.jpg
#   inflating: plants_dataset/corn/corn735.jpg
#   inflating: plants_dataset/corn/corn736.jpg
#   inflating: plants_dataset/corn/corn737.jpg
#   inflating: plants_dataset/corn/corn738.jpg
#   inflating: plants_dataset/corn/corn739.jpg
#   inflating: plants_dataset/corn/corn740.jpg
#   inflating: plants_dataset/corn/corn741.jpg
#   inflating: plants_dataset/corn/corn742.jpg
#   inflating: plants_dataset/corn/corn743.jpg
#   inflating: plants_dataset/corn/corn744.jpg
#   inflating: plants_dataset/corn/corn745.jpg
#   inflating: plants_dataset/corn/corn746.jpg
#   inflating: plants_dataset/corn/corn747.jpg
#   inflating: plants_dataset/corn/corn748.jpg
#   inflating: plants_dataset/corn/corn749.jpg
#   inflating: plants_dataset/corn/corn750.jpg
#   inflating: plants_dataset/corn/corn751.jpg
#   inflating: plants_dataset/corn/corn752.jpg
#   inflating: plants_dataset/corn/corn753.jpg
#   inflating: plants_dataset/corn/corn754.jpg
#   inflating: plants_dataset/corn/corn755.jpg
#   inflating: plants_dataset/corn/corn756.jpg
#   inflating: plants_dataset/corn/corn757.jpg
#   inflating: plants_dataset/corn/corn758.jpg
#   inflating: plants_dataset/corn/corn759.jpg
#   inflating: plants_dataset/corn/corn760.jpg
#   inflating: plants_dataset/corn/corn761.jpg
#   inflating: plants_dataset/corn/corn762.jpg
#   inflating: plants_dataset/corn/corn763.jpg
#   inflating: plants_dataset/corn/corn764.jpg
#   inflating: plants_dataset/corn/corn765.jpg
#   inflating: plants_dataset/corn/corn766.jpg
#   inflating: plants_dataset/corn/corn767.jpg
#   inflating: plants_dataset/corn/corn768.jpg
#   inflating: plants_dataset/corn/corn769.jpg
#   inflating: plants_dataset/corn/corn770.jpg
#   inflating: plants_dataset/corn/corn771.jpg
#   inflating: plants_dataset/corn/corn772.jpg
#   inflating: plants_dataset/corn/corn773.jpg
#   inflating: plants_dataset/corn/corn774.jpg
#   inflating: plants_dataset/corn/corn775.jpg
#   inflating: plants_dataset/corn/corn776.jpg
#   inflating: plants_dataset/corn/corn777.jpg
#   inflating: plants_dataset/corn/corn778.jpg
#   inflating: plants_dataset/corn/corn779.jpg
#   inflating: plants_dataset/corn/corn780.jpg
#   inflating: plants_dataset/corn/corn781.jpg
#   inflating: plants_dataset/corn/corn782.jpg
#   inflating: plants_dataset/corn/corn783.jpg
#   inflating: plants_dataset/corn/corn784.jpg
#   inflating: plants_dataset/corn/corn785.jpg
#   inflating: plants_dataset/corn/corn786.jpg
#   inflating: plants_dataset/corn/corn787.jpg
#   inflating: plants_dataset/corn/corn788.jpg
#   inflating: plants_dataset/corn/corn789.jpg
#   inflating: plants_dataset/corn/corn790.jpg
#   inflating: plants_dataset/corn/corn791.jpg
#   inflating: plants_dataset/corn/corn792.jpg
#   inflating: plants_dataset/corn/corn793.jpg
#   inflating: plants_dataset/corn/corn794.jpg
#   inflating: plants_dataset/corn/corn795.jpg
#   inflating: plants_dataset/corn/corn796.jpg
#   inflating: plants_dataset/corn/corn797.jpg
#   inflating: plants_dataset/corn/corn798.jpg
#   inflating: plants_dataset/corn/corn799.jpg
#   inflating: plants_dataset/cucumber/cucumber700.jpg
#   inflating: plants_dataset/cucumber/cucumber701.jpg
#   inflating: plants_dataset/cucumber/cucumber702.jpg
#   inflating: plants_dataset/cucumber/cucumber703.jpg
#   inflating: plants_dataset/cucumber/cucumber704.jpg
#   inflating: plants_dataset/cucumber/cucumber705.jpg
#   inflating: plants_dataset/cucumber/cucumber706.jpg
#   inflating: plants_dataset/cucumber/cucumber707.jpg
#   inflating: plants_dataset/cucumber/cucumber708.jpg
#   inflating: plants_dataset/cucumber/cucumber709.jpg
#   inflating: plants_dataset/cucumber/cucumber710.jpg
#   inflating: plants_dataset/cucumber/cucumber711.jpg
#   inflating: plants_dataset/cucumber/cucumber712.jpg
#   inflating: plants_dataset/cucumber/cucumber713.jpg
#   inflating: plants_dataset/cucumber/cucumber714.jpg
#   inflating: plants_dataset/cucumber/cucumber715.jpg
#   inflating: plants_dataset/cucumber/cucumber716.jpg
#   inflating: plants_dataset/cucumber/cucumber717.jpg
#   inflating: plants_dataset/cucumber/cucumber718.jpg
#   inflating: plants_dataset/cucumber/cucumber719.jpg
#   inflating: plants_dataset/cucumber/cucumber720.jpg
#   inflating: plants_dataset/cucumber/cucumber721.jpg
#   inflating: plants_dataset/cucumber/cucumber722.jpg
#   inflating: plants_dataset/cucumber/cucumber723.jpg
#   inflating: plants_dataset/cucumber/cucumber724.jpg
#   inflating: plants_dataset/cucumber/cucumber725.jpg
#   inflating: plants_dataset/cucumber/cucumber726.jpg
#   inflating: plants_dataset/cucumber/cucumber727.jpg
#   inflating: plants_dataset/cucumber/cucumber728.jpg
#   inflating: plants_dataset/cucumber/cucumber729.jpg
#   inflating: plants_dataset/cucumber/cucumber730.jpg
#   inflating: plants_dataset/cucumber/cucumber731.jpg
#   inflating: plants_dataset/cucumber/cucumber732.jpg
#   inflating: plants_dataset/cucumber/cucumber733.jpg
#   inflating: plants_dataset/cucumber/cucumber734.jpg
#   inflating: plants_dataset/cucumber/cucumber735.jpg
#   inflating: plants_dataset/cucumber/cucumber736.jpg
#   inflating: plants_dataset/cucumber/cucumber737.jpg
#   inflating: plants_dataset/cucumber/cucumber738.jpg
#   inflating: plants_dataset/cucumber/cucumber739.jpg
#   inflating: plants_dataset/cucumber/cucumber740.jpg
#   inflating: plants_dataset/cucumber/cucumber741.jpg
#   inflating: plants_dataset/cucumber/cucumber742.jpg
#   inflating: plants_dataset/cucumber/cucumber743.jpg
#   inflating: plants_dataset/cucumber/cucumber744.jpg
#   inflating: plants_dataset/cucumber/cucumber745.jpg
#   inflating: plants_dataset/cucumber/cucumber746.jpg
#   inflating: plants_dataset/cucumber/cucumber747.jpg
#   inflating: plants_dataset/cucumber/cucumber748.jpg
#   inflating: plants_dataset/cucumber/cucumber749.jpg
#   inflating: plants_dataset/cucumber/cucumber750.jpg
#   inflating: plants_dataset/cucumber/cucumber751.jpg
#   inflating: plants_dataset/cucumber/cucumber752.jpg
#   inflating: plants_dataset/cucumber/cucumber753.jpg
#   inflating: plants_dataset/cucumber/cucumber754.jpg
#   inflating: plants_dataset/cucumber/cucumber755.jpg
#   inflating: plants_dataset/cucumber/cucumber756.jpg
#   inflating: plants_dataset/cucumber/cucumber757.jpg
#   inflating: plants_dataset/cucumber/cucumber758.jpg
#   inflating: plants_dataset/cucumber/cucumber759.jpg
#   inflating: plants_dataset/cucumber/cucumber760.jpg
#   inflating: plants_dataset/cucumber/cucumber761.jpg
#   inflating: plants_dataset/cucumber/cucumber762.jpg
#   inflating: plants_dataset/cucumber/cucumber763.jpg
#   inflating: plants_dataset/cucumber/cucumber764.jpg
#   inflating: plants_dataset/cucumber/cucumber765.jpg
#   inflating: plants_dataset/cucumber/cucumber766.jpg
#   inflating: plants_dataset/cucumber/cucumber767.jpg
#   inflating: plants_dataset/cucumber/cucumber768.jpg
#   inflating: plants_dataset/cucumber/cucumber769.jpg
#   inflating: plants_dataset/cucumber/cucumber770.jpg
#   inflating: plants_dataset/cucumber/cucumber771.jpg
#   inflating: plants_dataset/cucumber/cucumber772.jpg
#   inflating: plants_dataset/cucumber/cucumber773.jpg
#   inflating: plants_dataset/cucumber/cucumber774.jpg
#   inflating: plants_dataset/cucumber/cucumber775.jpg
#   inflating: plants_dataset/cucumber/cucumber776.jpg
#   inflating: plants_dataset/cucumber/cucumber777.jpg
#   inflating: plants_dataset/cucumber/cucumber778.jpg
#   inflating: plants_dataset/cucumber/cucumber779.jpg
#   inflating: plants_dataset/cucumber/cucumber780.jpg
#   inflating: plants_dataset/cucumber/cucumber781.jpg
#   inflating: plants_dataset/cucumber/cucumber782.jpg
#   inflating: plants_dataset/cucumber/cucumber783.jpg
#   inflating: plants_dataset/cucumber/cucumber784.jpg
#   inflating: plants_dataset/cucumber/cucumber785.jpg
#   inflating: plants_dataset/cucumber/cucumber786.jpg
#   inflating: plants_dataset/cucumber/cucumber787.jpg
#   inflating: plants_dataset/cucumber/cucumber788.jpg
#   inflating: plants_dataset/cucumber/cucumber789.jpg
#   inflating: plants_dataset/cucumber/cucumber790.jpg
#   inflating: plants_dataset/cucumber/cucumber791.jpg
#   inflating: plants_dataset/cucumber/cucumber792.jpg
#   inflating: plants_dataset/cucumber/cucumber793.jpg
#   inflating: plants_dataset/cucumber/cucumber794.jpg
#   inflating: plants_dataset/cucumber/cucumber795.jpg
#   inflating: plants_dataset/cucumber/cucumber796.jpg
#   inflating: plants_dataset/cucumber/cucumber797.jpg
#   inflating: plants_dataset/cucumber/cucumber798.jpg
#   inflating: plants_dataset/cucumber/cucumber799.jpg
#   inflating: plants_dataset/curcuma/curcuma700.jpg
#   inflating: plants_dataset/curcuma/curcuma701.jpg
#   inflating: plants_dataset/curcuma/curcuma702.jpg
#   inflating: plants_dataset/curcuma/curcuma703.jpg
#   inflating: plants_dataset/curcuma/curcuma704.jpg
#   inflating: plants_dataset/curcuma/curcuma705.jpg
#   inflating: plants_dataset/curcuma/curcuma706.jpg
#   inflating: plants_dataset/curcuma/curcuma707.jpg
#   inflating: plants_dataset/curcuma/curcuma708.jpg
#   inflating: plants_dataset/curcuma/curcuma709.jpg
#   inflating: plants_dataset/curcuma/curcuma710.jpg
#   inflating: plants_dataset/curcuma/curcuma711.jpg
#   inflating: plants_dataset/curcuma/curcuma712.jpg
#   inflating: plants_dataset/curcuma/curcuma713.jpg
#   inflating: plants_dataset/curcuma/curcuma714.jpg
#   inflating: plants_dataset/curcuma/curcuma715.jpg
#   inflating: plants_dataset/curcuma/curcuma716.jpg
#   inflating: plants_dataset/curcuma/curcuma717.jpg
#   inflating: plants_dataset/curcuma/curcuma718.jpg
#   inflating: plants_dataset/curcuma/curcuma719.jpg
#   inflating: plants_dataset/curcuma/curcuma720.jpg
#   inflating: plants_dataset/curcuma/curcuma721.jpg
#   inflating: plants_dataset/curcuma/curcuma722.jpg
#   inflating: plants_dataset/curcuma/curcuma723.jpg
#   inflating: plants_dataset/curcuma/curcuma724.jpg
#   inflating: plants_dataset/curcuma/curcuma725.jpg
#   inflating: plants_dataset/curcuma/curcuma726.jpg
#   inflating: plants_dataset/curcuma/curcuma727.jpg
#   inflating: plants_dataset/curcuma/curcuma728.jpg
#   inflating: plants_dataset/curcuma/curcuma729.jpg
#   inflating: plants_dataset/curcuma/curcuma730.jpg
#   inflating: plants_dataset/curcuma/curcuma731.jpg
#   inflating: plants_dataset/curcuma/curcuma732.jpg
#   inflating: plants_dataset/curcuma/curcuma733.jpg
#   inflating: plants_dataset/curcuma/curcuma734.jpg
#   inflating: plants_dataset/curcuma/curcuma735.jpg
#   inflating: plants_dataset/curcuma/curcuma736.jpg
#   inflating: plants_dataset/curcuma/curcuma737.jpg
#   inflating: plants_dataset/curcuma/curcuma738.jpg
#   inflating: plants_dataset/curcuma/curcuma739.jpg
#   inflating: plants_dataset/curcuma/curcuma740.jpg
#   inflating: plants_dataset/curcuma/curcuma741.jpg
#   inflating: plants_dataset/curcuma/curcuma742.jpg
#   inflating: plants_dataset/curcuma/curcuma743.jpg
#   inflating: plants_dataset/curcuma/curcuma744.jpg
#   inflating: plants_dataset/curcuma/curcuma745.jpg
#   inflating: plants_dataset/curcuma/curcuma746.jpg
#   inflating: plants_dataset/curcuma/curcuma747.jpg
#   inflating: plants_dataset/curcuma/curcuma748.jpg
#   inflating: plants_dataset/curcuma/curcuma749.jpg
#   inflating: plants_dataset/curcuma/curcuma750.jpg
#   inflating: plants_dataset/curcuma/curcuma751.jpg
#   inflating: plants_dataset/curcuma/curcuma752.jpg
#   inflating: plants_dataset/curcuma/curcuma753.jpg
#   inflating: plants_dataset/curcuma/curcuma754.jpg
#   inflating: plants_dataset/curcuma/curcuma755.jpg
#   inflating: plants_dataset/curcuma/curcuma756.jpg
#   inflating: plants_dataset/curcuma/curcuma757.jpg
#   inflating: plants_dataset/curcuma/curcuma758.jpg
#   inflating: plants_dataset/curcuma/curcuma759.jpg
#   inflating: plants_dataset/curcuma/curcuma760.jpg
#   inflating: plants_dataset/curcuma/curcuma761.jpg
#   inflating: plants_dataset/curcuma/curcuma762.jpg
#   inflating: plants_dataset/curcuma/curcuma763.jpg
#   inflating: plants_dataset/curcuma/curcuma764.jpg
#   inflating: plants_dataset/curcuma/curcuma765.jpg
#   inflating: plants_dataset/curcuma/curcuma766.jpg
#   inflating: plants_dataset/curcuma/curcuma767.jpg
#   inflating: plants_dataset/curcuma/curcuma768.jpg
# ...
#   inflating: plants_dataset/tobacco/tobacco721.jpg
#   inflating: plants_dataset/tobacco/tobacco722.jpg
#   inflating: plants_dataset/tobacco/tobacco723.jpg
#   inflating: plants_dataset/tobacco/tobacco724.jpg
#   inflating: plants_dataset/tobacco/tobacco725.jpg
#   inflating: plants_dataset/tobacco/tobacco726.jpg
#   inflating: plants_dataset/tobacco/tobacco727.jpg
#   inflating: plants_dataset/tobacco/tobacco728.jpg
#   inflating: plants_dataset/tobacco/tobacco729.jpg
#   inflating: plants_dataset/tobacco/tobacco730.jpg
#   inflating: plants_dataset/tobacco/tobacco731.jpg
#   inflating: plants_dataset/tobacco/tobacco732.jpg
#   inflating: plants_dataset/tobacco/tobacco733.jpg
#   inflating: plants_dataset/tobacco/tobacco734.jpg
#   inflating: plants_dataset/tobacco/tobacco735.jpg
#   inflating: plants_dataset/tobacco/tobacco736.jpg
#   inflating: plants_dataset/tobacco/tobacco737.jpg
#   inflating: plants_dataset/tobacco/tobacco738.jpg
#   inflating: plants_dataset/tobacco/tobacco739.jpg
#   inflating: plants_dataset/tobacco/tobacco740.jpg
#   inflating: plants_dataset/tobacco/tobacco741.jpg
#   inflating: plants_dataset/tobacco/tobacco742.jpg
#   inflating: plants_dataset/tobacco/tobacco743.jpg
#   inflating: plants_dataset/tobacco/tobacco744.jpg
#   inflating: plants_dataset/tobacco/tobacco745.jpg
#   inflating: plants_dataset/tobacco/tobacco746.jpg
#   inflating: plants_dataset/tobacco/tobacco747.jpg
#   inflating: plants_dataset/tobacco/tobacco748.jpg
#   inflating: plants_dataset/tobacco/tobacco749.jpg
#   inflating: plants_dataset/tobacco/tobacco750.jpg
#   inflating: plants_dataset/tobacco/tobacco751.jpg
#   inflating: plants_dataset/tobacco/tobacco752.jpg
#   inflating: plants_dataset/tobacco/tobacco753.jpg
#   inflating: plants_dataset/tobacco/tobacco754.jpg
#   inflating: plants_dataset/tobacco/tobacco755.jpg
#   inflating: plants_dataset/tobacco/tobacco756.jpg
#   inflating: plants_dataset/tobacco/tobacco757.jpg
#   inflating: plants_dataset/tobacco/tobacco758.jpg
#   inflating: plants_dataset/tobacco/tobacco759.jpg
#   inflating: plants_dataset/tobacco/tobacco760.jpg
#   inflating: plants_dataset/tobacco/tobacco761.jpg
#   inflating: plants_dataset/tobacco/tobacco762.jpg
#   inflating: plants_dataset/tobacco/tobacco763.jpg
#   inflating: plants_dataset/tobacco/tobacco764.jpg
#   inflating: plants_dataset/tobacco/tobacco765.jpg
#   inflating: plants_dataset/tobacco/tobacco766.jpg
#   inflating: plants_dataset/tobacco/tobacco767.jpg
#   inflating: plants_dataset/tobacco/tobacco768.jpg
#   inflating: plants_dataset/tobacco/tobacco769.jpg
#   inflating: plants_dataset/tobacco/tobacco770.jpg
#   inflating: plants_dataset/tobacco/tobacco771.jpg
#   inflating: plants_dataset/tobacco/tobacco772.jpg
#   inflating: plants_dataset/tobacco/tobacco773.jpg
#   inflating: plants_dataset/tobacco/tobacco774.jpg
#   inflating: plants_dataset/tobacco/tobacco775.jpg
#   inflating: plants_dataset/tobacco/tobacco776.jpg
#   inflating: plants_dataset/tobacco/tobacco777.jpg
#   inflating: plants_dataset/tobacco/tobacco778.jpg
#   inflating: plants_dataset/tobacco/tobacco779.jpg
#   inflating: plants_dataset/tobacco/tobacco780.jpg
#   inflating: plants_dataset/tobacco/tobacco781.jpg
#   inflating: plants_dataset/tobacco/tobacco782.jpg
#   inflating: plants_dataset/tobacco/tobacco783.jpg
#   inflating: plants_dataset/tobacco/tobacco784.jpg
#   inflating: plants_dataset/tobacco/tobacco785.jpg
#   inflating: plants_dataset/tobacco/tobacco786.jpg
#   inflating: plants_dataset/tobacco/tobacco787.jpg
#   inflating: plants_dataset/tobacco/tobacco788.jpg
#   inflating: plants_dataset/tobacco/tobacco789.jpg
#   inflating: plants_dataset/tobacco/tobacco790.jpg
#   inflating: plants_dataset/tobacco/tobacco791.jpg
#   inflating: plants_dataset/tobacco/tobacco792.jpg
#   inflating: plants_dataset/tobacco/tobacco793.jpg
#   inflating: plants_dataset/tobacco/tobacco794.jpg
#   inflating: plants_dataset/tobacco/tobacco795.jpg
#   inflating: plants_dataset/tobacco/tobacco796.jpg
#   inflating: plants_dataset/tobacco/tobacco797.jpg
#   inflating: plants_dataset/tobacco/tobacco798.jpg
#   inflating: plants_dataset/tobacco/tobacco799.jpg
#   inflating: plants_dataset/waterapple/waterapple700.jpg
#   inflating: plants_dataset/waterapple/waterapple701.jpg
#   inflating: plants_dataset/waterapple/waterapple702.jpg
#   inflating: plants_dataset/waterapple/waterapple703.jpg
#   inflating: plants_dataset/waterapple/waterapple704.jpg
#   inflating: plants_dataset/waterapple/waterapple705.jpg
#   inflating: plants_dataset/waterapple/waterapple706.jpg
#   inflating: plants_dataset/waterapple/waterapple707.jpg
#   inflating: plants_dataset/waterapple/waterapple708.jpg
#   inflating: plants_dataset/waterapple/waterapple709.jpg
#   inflating: plants_dataset/waterapple/waterapple710.jpg
#   inflating: plants_dataset/waterapple/waterapple711.jpg
#   inflating: plants_dataset/waterapple/waterapple712.jpg
#   inflating: plants_dataset/waterapple/waterapple713.jpg
#   inflating: plants_dataset/waterapple/waterapple714.jpg
#   inflating: plants_dataset/waterapple/waterapple715.jpg
#   inflating: plants_dataset/waterapple/waterapple716.jpg
#   inflating: plants_dataset/waterapple/waterapple717.jpg
#   inflating: plants_dataset/waterapple/waterapple718.jpg
#   inflating: plants_dataset/waterapple/waterapple719.jpg
#   inflating: plants_dataset/waterapple/waterapple720.jpg
#   inflating: plants_dataset/waterapple/waterapple721.jpg
#   inflating: plants_dataset/waterapple/waterapple722.jpg
#   inflating: plants_dataset/waterapple/waterapple723.jpg
#   inflating: plants_dataset/waterapple/waterapple724.jpg
#   inflating: plants_dataset/waterapple/waterapple725.jpg
#   inflating: plants_dataset/waterapple/waterapple726.jpg
#   inflating: plants_dataset/waterapple/waterapple727.jpg
#   inflating: plants_dataset/waterapple/waterapple728.jpg
#   inflating: plants_dataset/waterapple/waterapple729.jpg
#   inflating: plants_dataset/waterapple/waterapple730.jpg
#   inflating: plants_dataset/waterapple/waterapple731.jpg
#   inflating: plants_dataset/waterapple/waterapple732.jpg
#   inflating: plants_dataset/waterapple/waterapple733.jpg
#   inflating: plants_dataset/waterapple/waterapple734.jpg
#   inflating: plants_dataset/waterapple/waterapple735.jpg
#   inflating: plants_dataset/waterapple/waterapple736.jpg
#   inflating: plants_dataset/waterapple/waterapple737.jpg
#   inflating: plants_dataset/waterapple/waterapple738.jpg
#   inflating: plants_dataset/waterapple/waterapple739.jpg
#   inflating: plants_dataset/waterapple/waterapple740.jpg
#   inflating: plants_dataset/waterapple/waterapple741.jpg
#   inflating: plants_dataset/waterapple/waterapple742.jpg
#   inflating: plants_dataset/waterapple/waterapple743.jpg
#   inflating: plants_dataset/waterapple/waterapple744.jpg
#   inflating: plants_dataset/waterapple/waterapple745.jpg
#   inflating: plants_dataset/waterapple/waterapple746.jpg
#   inflating: plants_dataset/waterapple/waterapple747.jpg
#   inflating: plants_dataset/waterapple/waterapple748.jpg
#   inflating: plants_dataset/waterapple/waterapple749.jpg
#   inflating: plants_dataset/waterapple/waterapple750.jpg
#   inflating: plants_dataset/waterapple/waterapple751.jpg
#   inflating: plants_dataset/waterapple/waterapple752.jpg
#   inflating: plants_dataset/waterapple/waterapple753.jpg
#   inflating: plants_dataset/waterapple/waterapple754.jpg
#   inflating: plants_dataset/waterapple/waterapple755.jpg
#   inflating: plants_dataset/waterapple/waterapple756.jpg
#   inflating: plants_dataset/waterapple/waterapple757.jpg
#   inflating: plants_dataset/waterapple/waterapple758.jpg
#   inflating: plants_dataset/waterapple/waterapple759.jpg
#   inflating: plants_dataset/waterapple/waterapple760.jpg
#   inflating: plants_dataset/waterapple/waterapple761.jpg
#   inflating: plants_dataset/waterapple/waterapple762.jpg
#   inflating: plants_dataset/waterapple/waterapple763.jpg
#   inflating: plants_dataset/waterapple/waterapple764.jpg
#   inflating: plants_dataset/waterapple/waterapple765.jpg
#   inflating: plants_dataset/waterapple/waterapple766.jpg
#   inflating: plants_dataset/waterapple/waterapple767.jpg
#   inflating: plants_dataset/waterapple/waterapple768.jpg
#   inflating: plants_dataset/waterapple/waterapple769.jpg
#   inflating: plants_dataset/waterapple/waterapple770.jpg
#   inflating: plants_dataset/waterapple/waterapple771.jpg
#   inflating: plants_dataset/waterapple/waterapple772.jpg
#   inflating: plants_dataset/waterapple/waterapple773.jpg
#   inflating: plants_dataset/waterapple/waterapple774.jpg
#   inflating: plants_dataset/waterapple/waterapple775.jpg
#   inflating: plants_dataset/waterapple/waterapple776.jpg
#   inflating: plants_dataset/waterapple/waterapple777.jpg
#   inflating: plants_dataset/waterapple/waterapple778.jpg
#   inflating: plants_dataset/waterapple/waterapple779.jpg
#   inflating: plants_dataset/waterapple/waterapple780.jpg
#   inflating: plants_dataset/waterapple/waterapple781.jpg
#   inflating: plants_dataset/waterapple/waterapple782.jpg
#   inflating: plants_dataset/waterapple/waterapple783.jpg
#   inflating: plants_dataset/waterapple/waterapple784.jpg
#   inflating: plants_dataset/waterapple/waterapple785.jpg
#   inflating: plants_dataset/waterapple/waterapple786.jpg
#   inflating: plants_dataset/waterapple/waterapple787.jpg
#   inflating: plants_dataset/waterapple/waterapple788.jpg
#   inflating: plants_dataset/waterapple/waterapple789.jpg
#   inflating: plants_dataset/waterapple/waterapple790.jpg
#   inflating: plants_dataset/waterapple/waterapple791.jpg
#   inflating: plants_dataset/waterapple/waterapple792.jpg
#   inflating: plants_dataset/waterapple/waterapple793.jpg
#   inflating: plants_dataset/waterapple/waterapple794.jpg
#   inflating: plants_dataset/waterapple/waterapple795.jpg
#   inflating: plants_dataset/waterapple/waterapple796.jpg
#   inflating: plants_dataset/waterapple/waterapple797.jpg
#   inflating: plants_dataset/waterapple/waterapple798.jpg
#   inflating: plants_dataset/waterapple/waterapple799.jpg
#   inflating: plants_dataset/watermelon/watermelon700.jpg
#   inflating: plants_dataset/watermelon/watermelon701.jpg
#   inflating: plants_dataset/watermelon/watermelon702.jpg
#   inflating: plants_dataset/watermelon/watermelon703.jpg
#   inflating: plants_dataset/watermelon/watermelon704.jpg
#   inflating: plants_dataset/watermelon/watermelon705.jpg
#   inflating: plants_dataset/watermelon/watermelon706.jpg
#   inflating: plants_dataset/watermelon/watermelon707.jpg
#   inflating: plants_dataset/watermelon/watermelon708.jpg
#   inflating: plants_dataset/watermelon/watermelon709.jpg
#   inflating: plants_dataset/watermelon/watermelon710.jpg
#   inflating: plants_dataset/watermelon/watermelon711.jpg
#   inflating: plants_dataset/watermelon/watermelon712.jpg
#   inflating: plants_dataset/watermelon/watermelon713.jpg
#   inflating: plants_dataset/watermelon/watermelon714.jpg
#   inflating: plants_dataset/watermelon/watermelon715.jpg
#   inflating: plants_dataset/watermelon/watermelon716.jpg
#   inflating: plants_dataset/watermelon/watermelon717.jpg
#   inflating: plants_dataset/watermelon/watermelon718.jpg
#   inflating: plants_dataset/watermelon/watermelon719.jpg
#   inflating: plants_dataset/watermelon/watermelon720.jpg
#   inflating: plants_dataset/watermelon/watermelon721.jpg
#   inflating: plants_dataset/watermelon/watermelon722.jpg
#   inflating: plants_dataset/watermelon/watermelon723.jpg
#   inflating: plants_dataset/watermelon/watermelon724.jpg
#   inflating: plants_dataset/watermelon/watermelon725.jpg
#   inflating: plants_dataset/watermelon/watermelon726.jpg
#   inflating: plants_dataset/watermelon/watermelon727.jpg
#   inflating: plants_dataset/watermelon/watermelon728.jpg
#   inflating: plants_dataset/watermelon/watermelon729.jpg
#   inflating: plants_dataset/watermelon/watermelon730.jpg
#   inflating: plants_dataset/watermelon/watermelon731.jpg
#   inflating: plants_dataset/watermelon/watermelon732.jpg
#   inflating: plants_dataset/watermelon/watermelon733.jpg
#   inflating: plants_dataset/watermelon/watermelon734.jpg
#   inflating: plants_dataset/watermelon/watermelon735.jpg
#   inflating: plants_dataset/watermelon/watermelon736.jpg
#   inflating: plants_dataset/watermelon/watermelon737.jpg
#   inflating: plants_dataset/watermelon/watermelon738.jpg
#   inflating: plants_dataset/watermelon/watermelon739.jpg
#   inflating: plants_dataset/watermelon/watermelon740.jpg
#   inflating: plants_dataset/watermelon/watermelon741.jpg
#   inflating: plants_dataset/watermelon/watermelon742.jpg
#   inflating: plants_dataset/watermelon/watermelon743.jpg
#   inflating: plants_dataset/watermelon/watermelon744.jpg
#   inflating: plants_dataset/watermelon/watermelon745.jpg
#   inflating: plants_dataset/watermelon/watermelon746.jpg
#   inflating: plants_dataset/watermelon/watermelon747.jpg
#   inflating: plants_dataset/watermelon/watermelon748.jpg
#   inflating: plants_dataset/watermelon/watermelon749.jpg
#   inflating: plants_dataset/watermelon/watermelon750.jpg
#   inflating: plants_dataset/watermelon/watermelon751.jpg
#   inflating: plants_dataset/watermelon/watermelon752.jpg
#   inflating: plants_dataset/watermelon/watermelon753.jpg
#   inflating: plants_dataset/watermelon/watermelon754.jpg
#   inflating: plants_dataset/watermelon/watermelon755.jpg
#   inflating: plants_dataset/watermelon/watermelon756.jpg
#   inflating: plants_dataset/watermelon/watermelon757.jpg
#   inflating: plants_dataset/watermelon/watermelon758.jpg
#   inflating: plants_dataset/watermelon/watermelon759.jpg
#   inflating: plants_dataset/watermelon/watermelon760.jpg
#   inflating: plants_dataset/watermelon/watermelon761.jpg
#   inflating: plants_dataset/watermelon/watermelon762.jpg
#   inflating: plants_dataset/watermelon/watermelon763.jpg
#   inflating: plants_dataset/watermelon/watermelon764.jpg
#   inflating: plants_dataset/watermelon/watermelon765.jpg
#   inflating: plants_dataset/watermelon/watermelon766.jpg
#   inflating: plants_dataset/watermelon/watermelon767.jpg
#   inflating: plants_dataset/watermelon/watermelon768.jpg
#   inflating: plants_dataset/watermelon/watermelon769.jpg
#   inflating: plants_dataset/watermelon/watermelon770.jpg
#   inflating: plants_dataset/watermelon/watermelon771.jpg
#   inflating: plants_dataset/watermelon/watermelon772.jpg
#   inflating: plants_dataset/watermelon/watermelon773.jpg
#   inflating: plants_dataset/watermelon/watermelon774.jpg
#   inflating: plants_dataset/watermelon/watermelon775.jpg
#   inflating: plants_dataset/watermelon/watermelon776.jpg
#   inflating: plants_dataset/watermelon/watermelon777.jpg
#   inflating: plants_dataset/watermelon/watermelon778.jpg
#   inflating: plants_dataset/watermelon/watermelon779.jpg
#   inflating: plants_dataset/watermelon/watermelon780.jpg
#   inflating: plants_dataset/watermelon/watermelon781.jpg
#   inflating: plants_dataset/watermelon/watermelon782.jpg
#   inflating: plants_dataset/watermelon/watermelon783.jpg
#   inflating: plants_dataset/watermelon/watermelon784.jpg
#   inflating: plants_dataset/watermelon/watermelon785.jpg
#   inflating: plants_dataset/watermelon/watermelon786.jpg
#   inflating: plants_dataset/watermelon/watermelon787.jpg
#   inflating: plants_dataset/watermelon/watermelon788.jpg
#   inflating: plants_dataset/watermelon/watermelon789.jpg
#   inflating: plants_dataset/watermelon/watermelon790.jpg
#   inflating: plants_dataset/watermelon/watermelon791.jpg
#   inflating: plants_dataset/watermelon/watermelon792.jpg
#   inflating: plants_dataset/watermelon/watermelon793.jpg
#   inflating: plants_dataset/watermelon/watermelon794.jpg
#   inflating: plants_dataset/watermelon/watermelon795.jpg
#   inflating: plants_dataset/watermelon/watermelon796.jpg
#   inflating: plants_dataset/watermelon/watermelon797.jpg
#   inflating: plants_dataset/watermelon/watermelon798.jpg
#   inflating: plants_dataset/watermelon/watermelon799.jpg

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, Subset, DataLoader, random_split
from torchvision import transforms
from PIL import Image

# %%
import helper_utils
import unittests

# %% [markdown]
# <a name='1---data-access'></a>
# ## 1 - Data Access

# %% [markdown]
# <a name='11---exploring-the-dataset'></a>
# ### 1.1 - Exploring the Dataset
#
# As you’ve already learned, the first step when working with any new dataset is to explore it. This involves understanding its structure, the types of data it contains, and identifying any potential issues such as missing values or outliers.

# %% [markdown]
# In this step, you’ll use the `print_data_folder_structure` function from `helper_utils` to print the dataset's folder layout.
# This will help you see how the files and directories are organized, a crucial step before you start loading and preprocessing the data.

# %%
path_dataset = './plants_dataset'

helper_utils.print_data_folder_structure(path_dataset, max_depth=1)
# Out:
# plants_dataset/
# ├── classname.txt
# ├── df_labels.csv
# ├── df_labels_orig.csv
# ├── aloevera/
# ├── banana/
# ├── bilimbi/
# ├── cantaloupe/
# ├── cassava/
# ├── coconut/
# ├── corn/
# ├── cucumber/
# ├── curcuma/
# ├── eggplant/
# ├── galangal/
# ├── ginger/
# ├── guava/
# ├── kale/
# ├── longbeans/
# ├── mango/
# ├── melon/
# ├── orange/
# ├── paddy/
# ├── papaya/
# ├── peperchili/
# ├── pineapple/
# ├── pomelo/
# ├── shallot/
# ├── soybeans/
# ├── spinach/
# ├── sweetpotatoes/
# ├── tobacco/
# ├── waterapple/
# └── watermelon/

# %% [markdown]
# You now have an initial understanding of the dataset structure:
# - `df_labels.csv`,
# - `classname.txt`,
# - One folder per class, each containing the images for that class (all in `.jpg` format).
#
# This information will be useful when you design your custom Dataset class later on.

# %%
# print the content of `df_labels.csv`
df_labels = pd.read_csv(f'{path_dataset}/df_labels.csv')
print(df_labels.head())
# Out:
#                  image:FILE  category
# 0  aloevera/aloevera700.jpg         0
# 1  aloevera/aloevera701.jpg         0
# 2  aloevera/aloevera702.jpg         0
# 3  aloevera/aloevera703.jpg         0
# 4  aloevera/aloevera704.jpg         0

# %%
# print the content of `class_names.txt`
with open(f'{path_dataset}/classname.txt', 'r') as f:
    class_names = f.read().splitlines()
print(class_names)
# Out:
# ['aloevera', 'banana', 'bilimbi', 'cantaloupe', 'cassava', 'coconut', 'corn', 'cucumber', 'curcuma', 'eggplant', 'galangal', 'ginger', 'guava', 'kale', 'longbeans', 'mango', 'melon', 'orange', 'paddy', 'papaya', 'peperchili', 'pineapple', 'pomelo', 'shallot', 'soybeans', 'spinach', 'sweetpotatoes', 'tobacco', 'waterapple', 'watermelon']

# %% [markdown]
# You’ve verified that `df_labels.csv` contains the labels for each image along with their corresponding file names, and that `classname.txt` contains the names of all the classes.

# %% [markdown]
# <a name='12---creating-a-custom-dataset-class'></a>
# ### 1.2 - Creating a Custom Dataset Class
#
# It is now time to create a custom dataset class to handle the plant images dataset.
# This class will inherit from `torch.utils.data.Dataset` and will be responsible for loading and preprocessing the images along with their corresponding labels.

# %% [markdown]
# <a name='exercise-1---plantsdataset'></a>
# #### **Exercise 1 - `PlantsDataset`**
#
# **Your Task:**
#
# Your task is to complete the implementation of the custom PyTorch Dataset class `PlantsDataset`.
# You need to implement the missing code in multiple sections within the class:
#
# * **Complete the `__init__` method**:
#     * Load labels from the DataFrame using the already defined `load_labels` method on the `.df_info` attribute.
#     * Create a mapping from label integers to class names using the already defined `read_classname` method.
#
# * **Complete the `__len__` method**:
#     * Return the total number of samples in the dataset by extracting the length of the `.labels` attribute.
#
# * **Complete the `__getitem__` method**:
#     * Retrieve the image at the specified index using the existing `retrieve_image` method.
#     * Apply transformations to the image if they are specified.
#     * Get the corresponding label from the `.labels` attribute.
#
# <details>
#   <summary><b><font color="green">Additional Code Hints (Click to expand if you are stuck)</font></b></summary>
#
# If you need a little help, here's a more detailed guide for each method:
#
# **For the `__init__` method:**
# * For `self.labels`: Call `self.load_labels()` to extract labels from the `self.df_info` DataFrame.
#
# **For the `__len__` method:**
# * Use the built-in `len()` function on `self.labels`.
#
# **For the `__getitem__` method:**
# * Use `self.retrieve_image(idx)` to get the image at the specified index.
# * If `self.transform` is not None, apply it to the image using `self.transform(image)`.
# * Get the label from `self.labels[idx]`.
#
# </details>

# %%
# GRADED CLASS: PlantsDataset
class PlantsDataset(Dataset):
    """
    ExDataset is a custom PyTorch Dataset for loading images and their corresponding labels from a specified directory and CSV file.

    Args:
        root_dir (str): Root directory containing the dataset files, including 'classname.txt'.
        transform (callable, optional): Optional transform to be applied on a sample.

    Attributes:
        root_dir (str): Path to the root directory of the dataset.
        transform (callable): Transformations to apply to the images.
        df_info (pd.DataFrame): DataFrame containing image file names and category labels.
        labels (list): List of integer labels for each image.
        class_names (list): List of class names corresponding to label indices.
    """

    def __init__(self, root_dir, transform=None):
        """
        Initializes the dataset object.

        Args:
            root_dir (str): Path to the root directory containing the dataset.
            transform (callable, optional): Optional transform to be applied on a sample.
        """

        # Initialize path to root directory and transformations
        self.root_dir = root_dir
        self.transform = transform

        # Read the CSV file (with images path and category labels)
        self.df_info = self.read_df()

        ### START CODE HERE ###

        # Load labels from the DataFrame using the `load_labels` method
        self.labels = self.load_labels(self.df_info)

        # Create a mapping from label integers to class names using the `read_classname` method
        self.class_names = self.read_classname()

        ### END CODE HERE ###

    def read_df(self):
        """
        Reads a CSV file from the specified path and returns it as a pandas DataFrame.
        """
        path_csv = self.root_dir + "/df_labels.csv"
        df = pd.read_csv(path_csv)
        return df

    def read_classname(self):
        """
        Reads class names from a file named 'classname.txt' located in the root directory.

        Returns:
            list: A list of class names, each as a string, read from the file.
        """
        path_txt = self.root_dir + "/classname.txt"
        with open(path_txt, "r") as f:
            class_names = f.read().splitlines()
        return class_names

    def load_labels(self, df):
        """
        Extracts label integers from a DataFrame and returns them as a list.
        """
        labels = []

        for idx, row in df.iterrows():
            label_int = row["category"]
            labels.append(label_int)
        return labels

    def get_label_description(self, label: int):
        """
        Returns the description of a class label.
        """
        description = self.class_names[label]
        return description

    def retrieve_image(self, idx: int):
        """
        Retrieves and returns from the folder the PIL image at the specified index.
        It converts the image to RGB mode.
        """
        img_path = self.root_dir + "/" + self.df_info.iloc[idx]["image:FILE"]
        with Image.open(img_path) as img:
            image = img.convert("RGB")
        return image

    ### START CODE HERE ###

    def __len__(self):
        """
        Returns the number of samples in the dataset.
        """
        # Return the total number of samples from the `.labels` attribute
        length = len(self.labels)
        return length

    def __getitem__(self, idx):
        """
        Retrieves the image and its corresponding label at the specified index.

        Args:
            idx (int): Index of the item to retrieve.

        Returns:
            tuple: A tuple (image, label) where:
                - image: The image at the given index, possibly transformed if a transform is specified.
                - label: The label corresponding to the image.
        """
        # Retrieve the image using the `retrieve_image` method
        image = self.retrieve_image(idx)

        # Apply the specified transformations to the image, if any
        # The None of the if condition is not part of the exercise, leave it as is
        if self.transform is not None:
            image = self.transform(image)


        # Retrieve the label from the `labels` attribute
        label = self.labels[idx]

        # Return the image and label
        return image, label

    ### END CODE HERE ###

# %%
plants_dataset = PlantsDataset(root_dir=path_dataset, transform=None)

# %%
# print the length of the dataset
print(f'Length of the dataset: {len(plants_dataset)}')
# Out:
# Length of the dataset: 3000

# %%
# Look at a sample to check it's working correctly
sel_idx = 10
img, label = plants_dataset[sel_idx]

# Visualize the image
helper_utils.plot_img(img)

# Print its description
print(f'Description: {plants_dataset.get_label_description(label)}')

# Print its shape
print(f'Image shape: {img.size}')  # PIL image size is (width, height)
# Out:
# Description: aloevera
# Image shape: (269, 187)

# %% [markdown]
# ##### **Expected Output**
# ```
# Description: aloevera
# Image shape: (269, 187)
# ```
#
# ![exp_out_1.png](exp_out_1.png)

# %%
# Test your code!
unittests.exercise_1(PlantsDataset)
# Out:
#  All tests passed!

# %% [markdown]
# <a name='13---overview-of-the-images-in-the-dataset'></a>
# ### 1.3 - Overview of the images in the dataset
#
# The images are now accessible through the custom dataset class you implemented in the previous exercise. However, they haven’t been preprocessed yet, a necessary step before feeding them into a neural network.
#
# In this step, you’ll explore the dataset using the `visual_exploration` function from `helper_utils`.
# This function displays a few sample images along with their labels, allowing you to visually inspect the data and get a sense of its main characteristics.

# %%
helper_utils.visual_exploration(plants_dataset, num_rows=2, num_cols=4)

# %% [markdown]
# From the visual exploration, you can see that the images in the dataset vary in size, color, and background.
# This kind of variability is common in real-world datasets and underscores the importance of preprocessing steps such as resizing, normalization, and data augmentation to help the model generalize effectively across different types of images.

# %% [markdown]
# <a name='2---transformations'></a>
# ## 2 - Transformations
#
# Before feeding images into a neural network, you need to preprocess them using a series of transformations.
# These steps include resizing the images to a consistent size, converting them into tensors, and normalizing their pixel values.

# %% [markdown]
# <a name='21---computing-mean-and-standard-deviation'></a>
# ### 2.1 - Computing Mean and Standard Deviation
#
# Below is an auxiliary function, `get_mean_std`, that computes the mean and standard deviation of the dataset. Both values are needed for the normalization transformation later on.
#
# The normalization transform will be applied after resizing and converting the images to tensors.
# Since these two transformations change the pixel value distribution, it’s important to compute the mean and standard deviation after they are applied.
#
# In `get_mean_std` you will:
#
# * **Preprocessing Setup**: Create a transform pipeline that resizes images to 128×128 and converts PIL images to tensors.
# * **Per-Image Processing**: Loop through each image in the dataset, applying the transforms and computing the mean and standard deviation across spatial dimensions (height/width) using `dim=[1, 2]`
# * **Statistics Collection**: Store each image’s channel-wise statistics in separate lists (`means` and `stds`)
# * **Global Calculation**: Stack all per-image statistics into tensors and average across all images to get dataset-wide channel statistics.

# %%
def get_mean_std(dataset: Dataset):
    # Define deterministic preprocessing (resize) + ToTensor
    preprocess = transforms.Compose(
        [transforms.Resize((128, 128)), transforms.ToTensor()]
    )

    # Lists to store per-image statistics
    means = []
    stds = []

    for img, _ in dataset:  # _ is the label
        # img is a PIL Image
        img_tensor = preprocess(img)
        means.append(img_tensor.mean(dim=[1, 2]))
        stds.append(img_tensor.std(dim=[1, 2]))

    # Stack and compute overall mean/std
    mean = torch.stack(means).mean(dim=0)
    std = torch.stack(stds).mean(dim=0)

    return mean, std

# %%
# Define the transformations to make to the images
mean, std = get_mean_std(plants_dataset)

print(f"Mean: {mean}, Std: {std}")
# Out:
# Mean: tensor([0.6659, 0.6203, 0.4784]), Std: tensor([0.2119, 0.2155, 0.2567])

# %% [markdown]
# <a name='22---defining-transformations'></a>
# ### 2.2 - Defining Transformations
#
# Having computed the mean and standard deviation of the dataset, you can now define the transformations to apply to the images.
# You’ll create two sets of transformations: one for the training set, which includes data augmentation, and another for the validation and test sets.

# %% [markdown]
# <a name='exercise-2---get_transformations'></a>
# #### **Exercise 2 - `get_transformations`**
#
# **Your Task:**
#
# Your task is to implement the missing code in the `get_transformations` function to create two image transformation pipelines for PyTorch.
#
# You will implement the following sections:
#
# * **Define `main_tfs`**:
#     * Create a `Resize` transform to resize images to 128x128 pixels.
#     * Create a `ToTensor` transform to convert PIL images to PyTorch tensors.
#     * Create a `Normalize` transform using the provided mean and standard deviation values.
#
# * **Define `augmentation_tfs`**:
#     * Create a `RandomVerticalFlip` transform with 50% probability.
#     * Create a `RandomRotation` transform that rotates images by ±15 degrees.
#
# * **Compose Transform Pipelines**:
#     * Create `main_transform` by combining the main transforms into a single pipeline using `transforms.Compose`.
#     * Create `transform_with_augmentation` by combining both augmentation and main transforms into an augmented pipeline.
#     The augmentation transforms should be applied before the main transforms.
#
#
# <details>
#   <summary><b><font color="green">Additional Code Hints (Click to expand if you are stuck)</font></b></summary>
#
# If you need a little help, here's a more detailed guide for each section:
#
# **For `main_tfs`:**
# * For `Resize`: Use `transforms.Resize((128, 128))` to resize all images to 128x128 pixels.
# * For `ToTensor`: Use `transforms.ToTensor()` to convert PIL images to PyTorch tensors.
# * For `Normalize`: Use `transforms.Normalize(mean=mean, std=std)` with the provided mean and std parameters.
#
#
# **For `augmentation_tfs`:**
# * For `RandomVerticalFlip`: Use `transforms.RandomVerticalFlip(p=0.5)` to flip images vertically with 50% probability.
# * For `RandomRotation`: Use `transforms.RandomRotation(degrees=15)` to rotate images randomly within ±15 degrees.
#
#
# **For composing transforms:**
# * For `main_transform`: Use `transforms.Compose(main_tfs)` to combine the main transforms list.
# * For `transform_with_augmentation`: Use `transforms.Compose(augmentation_tfs + main_tfs)` to combine both lists.
#
# </details>

# %%
# GRADED FUNCTION : get_transformations
def get_transformations(mean, std):
    """
    Returns two sets of image transformation pipelines: one with basic preprocessing and another with additional data augmentation.

    Args:
        mean: Sequence of mean values for normalization.
        std: Sequence of standard deviation values for normalization.

    Returns:
        main_transform: Transformation pipeline with resizing, tensor conversion, and normalization.
        transform_with_augmentation: Transformation pipeline including random vertical flip, random rotation, resizing, tensor conversion, and normalization.
    """
    ### START CODE HERE ###
    main_tfs = [
        # Resize images to 128x128 pixels
        transforms.Resize((128, 128)),
        # Convert images to PyTorch tensors
        transforms.ToTensor(),
        # Normalize images using the provided mean and std
        transforms.Normalize(mean, std)
    ]

    augmentation_tfs = [
        # Randomly flip the image vertically
        transforms.RandomVerticalFlip(p=0.5),
        # Randomly rotate the image by ±15 degrees
        transforms.RandomRotation(degrees=15)
    ]

    # Compose the main transformations into a single pipeline
    main_transform = transforms.Compose(main_tfs)

    transform_with_augmentation = transforms.Compose(augmentation_tfs + main_tfs)

    ### END CODE HERE ###
    return main_transform, transform_with_augmentation

# %%
# Get the transformations
main_transform, transform_with_augmentation = get_transformations(mean, std)

# Print the transformations to verify
print(main_transform)
print(transform_with_augmentation)
# Out:
# Compose(
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# Compose(
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )

# %% [markdown]
# ##### **Expected Output**
#
# ```
# Compose(
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# Compose(
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# ```

# %%
# Test your code!
unittests.exercise_2(get_transformations)
# Out:
#  All tests passed!

# %% [markdown]
# You can verify your transformations by applying them to a sample image from the dataset and inspecting the result.

# %%
# Check main_transform on a sample image
img_transformed = main_transform(img)
print(f"Transformed Image shape: {img_transformed.shape}")


# get denormalization function
denormalize = helper_utils.Denormalize(mean, std)
# visualize the augmented image
img_augmented = transform_with_augmentation(img)
helper_utils.plot_img(denormalize(img_augmented), info=f"Augmented Image")
# Out:
# Transformed Image shape: torch.Size([3, 128, 128])

# %% [markdown]
# <a name='3---data-loading'></a>
# ## 3 - Data Loading
#
# With your custom dataset class and transformations defined, you can now create data loaders to efficiently load and batch data for training and evaluation. This is the final step before you would train a neural network on this dataset.
#
# As in the previous lab, after using `random_split` to divide the dataset into training, validation, and test sets, you need to ensure that each subset uses the appropriate transformations.
# One way to change the transformations of each subset is by wrapping the subsets in new instances of the custom dataset class `SubsetWithTransform`.

# %%
class SubsetWithTransform(Dataset):
    """A subset of a dataset with a specific transform applied."""

    def __init__(self, subset: Subset, transform=None):
        # subset should be a subset WITHOUT transform
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        image, label = self.subset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# <a name='exercise-3---get_data_loaders'></a>
# #### **Exercise 3 - `get_data_loaders`**
#
# **Your Task:**
#
# Your task is to complete the implementation of the `get_dataloaders` function to split a dataset and create PyTorch DataLoaders for training, validation, and testing.
# You need to implement the missing code in three main sections:
#
# * **Split the Dataset**:
#     * Use `random_split` to divide the dataset into training, validation, and test sets based on the calculated sizes.
#
# * **Apply Transforms to Each Split**:
#     * Wrap each dataset split with `SubsetWithTransform` to apply appropriate transforms.
#     * Use `augmentation_transform` for the training set to include data augmentation.
#     * Use `main_transform` for both validation and test sets (no augmentation needed).
#
# * **Create DataLoaders**:
#     * Create `DataLoader` objects for each dataset split with the specified batch size.
#     * Enable shuffling for the training loader to randomize batch order.
#     * Disable shuffling for validation and test loaders to maintain consistent evaluation.
#
# <details>
#   <summary><b><font color="green">Additional Code Hints (Click to expand if you are stuck)</font></b></summary>
#
# If you need a little help, here's a more detailed guide for each section:
#
# **For splitting the dataset:**
# * Use `random_split(dataset, [train_size, val_size, test_size])` to split the dataset.
#
# **For applying transforms:**
# * Use `SubsetWithTransform(dataset_split, transform=transform_to_apply)` for each split.
#
# **For creating DataLoaders:**
# * Use `DataLoader(dataset=dataset_split, batch_size=batch_size, shuffle=shuffle_setting)`.
# * For training loader: set `shuffle=True` to randomize the order of batches.
# * For validation and test loaders: set `shuffle=False` to maintain consistent order for evaluation.
# * All loaders should use the same `batch_size` parameter.
#
# </details>

# %%
# GRADED FUNCTION : get_dataloaders
def get_dataloaders(
    dataset,
    batch_size,
    val_fraction,
    test_fraction,
    main_transform,
    augmentation_transform,
):
    """
    Splits a dataset into training, validation, and test sets, applies specified transforms to each split,
    and returns corresponding DataLoader objects.

    Args:
        dataset: The full dataset to be split.
        batch_size: Number of samples per batch to load.
        val_fraction: Fraction of the dataset to use for validation.
        test_fraction: Fraction of the dataset to use for testing.
        main_transform: Transform to apply to validation and test splits.
        augmentation_transform: Transform to apply to the training split.

    Returns:
        train_loader: DataLoader for the training set with augmentation transforms.
        val_loader: DataLoader for the validation set with main transforms.
        test_loader: DataLoader for the test set with main transforms.
    """

    # Calculate the sizes of each split
    total_size = len(dataset)
    val_size = int(total_size * val_fraction)
    test_size = int(total_size * test_fraction)
    train_size = total_size - val_size - test_size

    ### START CODE HERE ###

    # Split the dataset into training, validation, and test sets
    train_dataset, val_dataset, test_dataset = random_split(
            dataset, [train_size, val_size, test_size]
    )

    # Create dataset with the corresponding transforms for each split
    train_dataset = SubsetWithTransform(train_dataset, augmentation_transform)
    val_dataset = SubsetWithTransform(val_dataset, main_transform)
    test_dataset = SubsetWithTransform(test_dataset, main_transform)

    # Create DataLoaders for each split
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False   )
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    ### END CODE HERE ###
    return train_loader, val_loader, test_loader

# %%
train_loader, val_loader, test_loader = get_dataloaders(
    dataset=plants_dataset,
    batch_size=32,
    val_fraction=0.15,
    test_fraction=0.2,
    main_transform=main_transform,
    augmentation_transform=transform_with_augmentation,
)

# %%
print('=== Train Loader ===')
print(f"Number of batches in train_loader: {len(train_loader)}")
train_dataset = train_loader.dataset
print(f"Number of samples in train_dataset: {len(train_dataset)}")
print(f"Transforms applied to train_dataset: {train_dataset.transform}")
print(f"train_dataset type: {type(train_dataset)}")

print('\n=== Test Loader ===')
print(f"Number of batches in test_loader: {len(test_loader)}")
test_dataset = test_loader.dataset
print(f"Number of samples in test_dataset: {len(test_dataset)}")
print(f"Transforms applied to test_dataset: {test_dataset.transform}")
print(f"test_dataset type: {type(test_dataset)}")
# Out:
# === Train Loader ===
# Number of batches in train_loader: 61
# Number of samples in train_dataset: 1950
# Transforms applied to train_dataset: Compose(
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# train_dataset type: <class '__main__.SubsetWithTransform'>
#
# === Test Loader ===
# Number of batches in test_loader: 19
# Number of samples in test_dataset: 600
# Transforms applied to test_dataset: Compose(
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# test_dataset type: <class '__main__.SubsetWithTransform'>

# %% [markdown]
# ##### **Expected Output**
#
# ```
# === Train Loader ===
# Number of batches in train_loader: 61
# Number of samples in train_dataset: 1950
# Transforms applied to train_dataset: Compose(
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# train_dataset type: <class 'helper_utils.SubsetWithTransform'>
#
# === Test Loader ===
# Number of batches in test_loader: 19
# Number of samples in test_dataset: 600
# Transforms applied to test_dataset: Compose(
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=tensor([0.6659, 0.6203, 0.4784]), std=tensor([0.2119, 0.2155, 0.2567]))
# )
# test_dataset type: <class 'helper_utils.SubsetWithTransform'>
# ```

# %%
# Test your code!
unittests.exercise_3(get_dataloaders, plants_dataset)
# Out:
#  All tests passed!

# %% [markdown]
# ---
# # Submission Note
#
# Congratulations! You've completed the final graded exercise of this assignment.
#
# If you've successfully passed all the unit tests above, you've completed the core requirements of this assignment. Feel free to [submit](#submission) your work now. The grading process runs in the background, so it will not disrupt your progress and you can continue on with the rest of the material.
#
# **🚨 IMPORTANT NOTE** If you have passed all tests within the notebook, but the autograder shows a system error after you submit your work:
#
# <div style="background-color: #1C1C1E; border: 1px solid #444444; color: #FFFFFF; padding: 15px; border-radius: 5px;">
#     <p><strong>Grader Error: Grader feedback not found</strong></p>
#     <p>Autograder failed to produce the feedback...</p>
# </div>
# <br>
#
# This is typically a temporary system glitch. The most common solution is to resubmit your assignment, as this often resolves the problem. Occasionally, it may be necessary to resubmit more than once.
# >
# If the error persists, please reach out for support in the [DeepLearning.AI Community Forum](https://community.deeplearning.ai/c/course-q-a/pytorch-for-developers/pytorch-fundamentals/560).
#
# ---

# %% [markdown]
# ## Conclusion
#
# Congratulations! You have now built an end-to-end data pipeline in PyTorch.
#
# In this lab, you learned how to construct a complete pipeline to handle a real-world image dataset. You moved beyond basic data loading to explore the core components that make up a PyTorch data pipeline.
#
# You created a custom **`Dataset`** for **data access**, defined a sequence of **transformations** such as resizing, normalization, and data augmentation to improve training robustness, split the dataset into training, validation, and test sets, and used **`DataLoader`** for efficient for efficient batching and iteration.
#
# With these fundamental components—`Dataset`, `Transforms`, and `DataLoader`—you now have a clean, efficient, and reusable workflow for preparing any image dataset for training a neural network.
